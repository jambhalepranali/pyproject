# %%
matplotlib

# %%
x=[21,35,56,45,62]
y=[45,62,87,63,78]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)
plt.title('Line graf')
plt.xlabel('ages')
plt.ylabel('per')
plt.legend('name')
plt.show()

# %%
Scatterplot

# %%
age=[21,32,45,65,48,31,36]
sal=[1235555,300000,40000,456666,350000,8000000,600000]

# %%
plt.scatter(age,sal)

# %%
import pandas as pd

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8C6C-E259
#
#  Directory of C:\Users\ADMIN\Desktop\ML
#
# 01-10-2023  13:37    <DIR>          .
# 01-10-2023  13:37    <DIR>          ..
# 01-10-2023  13:15    <DIR>          .ipynb_checkpoints
# 29-09-2019  08:41           938,020 Bengaluru_House_Data.csv
# 23-09-2023  15:50    <DIR>          Numpy
# 19-09-2023  14:08    <DIR>          Pandas
# 01-10-2023  13:37            58,857 Untitled.ipynb
#                2 File(s)        996,877 bytes
#                5 Dir(s)  56,385,290,240 bytes free

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
plt.scatter(df['area_type'],df['price'])

# %%
team=[2012,2013,2014,2015,2016]
runs=[300,450,562,400,320]

# %%
plt.bar(team,runs)
# Out:
# <BarContainer object of 5 artists>

# %%
# importing pandas library
import pandas as pd
# import matplotlib library
import matplotlib.pyplot as plt
  
# creating dataframe
df = pd.DataFrame({
    'Name': ['John', 'Sammy', 'Joe'],
    'Age': [45, 38, 90],
    'Height(in cm)': [150, 180, 160]
})
  
# plotting graph
df.plot(x="Name", y=["Age", "Height(in cm)"], kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
piechart

# %%
party=['bjp','congres','aap','mns']
votes=[100,2000,350,450]

# %%
plt.pie(votes,labels=party,shadow=True,explode(0.25,0,0,0.30))
# Out:
#   Cell In[27], line 1
#     plt.pie(votes,labels=party,shadow=True,explode(0.25,0,0,0.30))
#                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.pie(votes,labels=party,shadow = True,explode =(0.25,0,0,0.30), autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x15f6e0a3880>,
# ...
#  [Text(1.34208624221729, 0.14596067433070423, 'bjp'),
#   Text(-0.7985950698120945, 0.7564693744440788, 'congres'),
#   Text(0.23646755880124057, -1.0742825948671895, 'aap'),
#   Text(1.2369168902768688, -0.6557717640671947, 'mns')],
#  [Text(0.8450172636182935, 0.09190116531933228, '3%'),
#   Text(-0.43559731080659697, 0.4126196587876793, '69%'),
#   Text(0.12898230480067666, -0.5859723244730124, '12%'),
#   Text(0.7951608580351299, -0.42156756261462514, '16%')])
